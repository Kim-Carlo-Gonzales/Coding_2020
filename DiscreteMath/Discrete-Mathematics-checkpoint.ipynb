# %% [markdown]
# # Activity 1
# ## Q: Ask for additional fries to the order<br>
# ## R: ask for additional drinks to the order <br>
# ## S: the costumer buy a cheeseburger deluxe <br>
# ## U: Throw in a sundae<br>
# ## V: Print the receipt <br>
# ## WFF $ S\rightarrow (Q \land R)\land U)\land V $

# %% [markdown]
# ## Flow Chart
# ![act1.png](attachment:act1.png)

# %%
CB_Delux = True
Sundae = False
Fries = False
Drinks = False
Give_receipt = False
if CB_Delux:
    Drinks =True
    Fries = True
    Sundae = True
    print("Here is your order, Enjoy Your Meal!")
    Give_receipt = True
    print("Receipt:",Give_receipt," Drinks:",Drinks," Fries:",Fries," Sundae:",Sundae," CheeseBurger Delux:",CB_Delux)
# Out:
# Here is your order, Enjoy Your Meal!
# Receipt: True  Drinks: True  Fries: True  Sundae: True  CheeseBurger Delux: True

# %% [markdown]
# # Activity 2
# ## English Statement: If the pool is less than or equal to 10 and reservoir is greater than 20, Make pool equal to 10.
# ## Q: pool is less than 10 <br>
# ## R: pool is equal to 10 <br>
# ## S: reservoir is greater than 20 <br>
# ## U: Make pool equal to reservoir <br>
# ## WFF: ((QvR)^S) --> U <br>

# %% [markdown]
# ## Flow Chart
# ![act2.png](attachment:act2.png)

# %%
def transfer_to_resource(reservoir,pool):
    if pool <= 10 and reservoir > 20:
        pool = reservoir
    return pool
print (pool)

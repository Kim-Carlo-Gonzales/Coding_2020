# %% [markdown]
# # Linear Algebra for CpE
# ## Laboratory 3 : Linear Combination and Vector Spaces
# Coded and submitted by:
# Gonzales, Kim Carlo M.
# 58010
#
# Lab Exercises: 3

# %% [markdown]
# Now that you have a fundamental knowledge about linear combination, we'll try to visualize it using scientific programming.

# %% [markdown]
# ### Objectives
# At the end of this activity you will be able to:
# 1. Be familiar with representing linear combinations in the 2-dimensional plane.
# 2. Visualize spans using vector fields in Python.
# 3. Perform vector fields operations using scientific programming.

# %% [markdown]
# ## Discussion

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Linear Combination

# %% [markdown]
# It is said that a linear combination is the combination of linear scaling and addition of a vector its bases/components

# %% [markdown]
# We will try to visualize the vectors and their linear combinations by plotting a sample of real number values for the scalars for the vectors. Let's first try the vectors below:

# %% [markdown]
# $$X = \begin{bmatrix} 2\\5 \\\end{bmatrix} , Y = \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
vectX =  np.array([2,5])
vectY =  np.array([7,9])

# %% [markdown]
# #### Span of single vectors

# %% [markdown]
# As discussed in the lecture, the span of individual vectors can be represented by a line span. Let's take vector $X$ as an example.

# %% [markdown]
# $$X = c\cdot \begin{bmatrix} 2\\5 \\\end{bmatrix} $$

# %%
c = np.arange(-10,10,0.25)

plt.scatter(c*vectX[0],c*vectX[1])

plt.xlim(-10,10)
plt.ylim(-10,10)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ### Span of a linear combination of vectors

# %% [markdown]
# So what if we are to plot the span of a linear combination of vectors? We can visualize as a plane on the 2-dimensional coordinate system. Let's take the span of the linear combination below:

# %% [markdown]
# $$S = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 1\\0 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} 1\\-1 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectA = np.array([1,0])
vectB = np.array([1,-1])
R = np.arange(-10,10,1)
c1, c2 = np.meshgrid(R,R)
vectR = vectA + vectB
spanRx = c1*vectA[0] + c2*vectB[0]
spanRy = c1*vectA[1] + c2*vectB[1]
# plt.scatter(R*vectA[0],R*vectA[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# Take note that if vectors are seen to be as a 2-dimensional span we can say it has a Rank of 2 or $\mathbb{R}^2$. But if the span of the linear combination of vectors are seen to be like a line, they are said to be <b> linearly dependent </b> and they have a rank of 1 or $\mathbb{R}^1$.

# %% [markdown]
# # Activity

# %% [markdown]
# ### Task 1

# %% [markdown]
# Try different linear combinations using different scalar values. In your methodology discuss the different functions that you have used, the  linear equation and vector form of the linear combination, and the flowchart for declaring and displaying linear combinations. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the linear combination visualization you made. You should use the cells below for displaying the equation markdows using LaTeX and your code.

# %% [markdown]
# ### Linear Combinations
# Linear Equations:
# 1. A = 5x + 7y <br>
# 2. B = -10x + 10y <br>
# 3. C = 15x + y <br>
# 4. D = x + 15y

# %% [markdown]
# Vector Form:
# $$
#     A = \begin{bmatrix} 5\\7 \\\end{bmatrix},
#     B = \begin{bmatrix} -10\\10 \\\end{bmatrix},
#     C = \begin{bmatrix} 15\\1 \\\end{bmatrix},
#     D = \begin{bmatrix} 1\\15 \\\end{bmatrix}
# $$

# %%
# VECTORS
vectorA = np.array([5,7])
vectorB = np.array([-10,10])
vectorC = np.array([15,1])
vectorD = np.array([1,15])

#For plotting the vectors

##for the vector lines
a = np.arange(-10,10,1)
b = np.arange(-10,10,.50)
c = np.arange(-10,10,.25)
d = np.arange(-10,10,.50)
plt.scatter(a*vectorA[0],a*vectorA[1])
plt.scatter(b*vectorB[0],b*vectorB[1])
plt.scatter(c*vectorC[0],c*vectorC[1])
plt.scatter(d*vectorD[0],d*vectorD[1])


##Configuration for the cartesian plane
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()

##shows the cartesian plane
plt.show()

# %% [markdown]
# #### Flowchart
# ![4thflow.png](attachment:4thflow.png)

# %% [markdown]
# ### Task 2

# %% [markdown]
# Try making three unque spans using different linear combinations . In your methodology discuss the different functions that you have used, the  linear equations and vector form of span, and the flowchart for declaring and displaying span. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the span visualization you made. You should use the cells below for displaying the equation markdows using LaTeX and your code.

# %% [markdown]
# ### Linear Combinations
# Linear equation
# 1. A = 5x + 7y <br>
# 2. B = -10x + 10y <br>
# 3. C = 15x + y <br>
# 4. D = x + 15y

# %% [markdown]
# vector form of span:
# $$S_1 = \begin{Bmatrix} a \cdot\begin{bmatrix} 5\\7 \\\end{bmatrix},
# b \cdot \begin{bmatrix} -10\\10 \\\end{bmatrix}\end{Bmatrix} $$
#
# $$S_2 = \begin{Bmatrix} c \cdot\begin{bmatrix} 15\\1 \\\end{bmatrix},
# d \cdot \begin{bmatrix} 1\\15 \\\end{bmatrix}\end{Bmatrix} $$
#
# $$S_3 = \begin{Bmatrix} e \cdot\begin{bmatrix} 7\\3 \\\end{bmatrix},
# f \cdot \begin{bmatrix} 21\\5 \\\end{bmatrix}\end{Bmatrix} $$

# %%
#function  for plotting span
def plot_vectors(vectorX,vectorY,X,Y):
    R = np.arange(-10,10,1.25)
    X, Y = np.meshgrid(R,R)
    vectorR = vectorX + vectorY
    spanRx = X*vectorX[0] + Y*vectorY[0]
    spanRy = X*vectorA[1] + Y*vectorB[1]

    plt.scatter(spanRx,spanRy, s=15, alpha=1)

    plt.axhline(y=0, color='k')
    plt.axvline(x=0, color='k')
    plt.grid()
    plt.show()
#Example 1
vectorA = np.array([5,7])
vectorB = np.array([-10,10])
plot_vectors(vectorA,vectorB,a,b)

# %%
#Example 2
vectorC = np.array([15,1])
vectorD = np.array([1,15]) 
plot_vectors(vectorC,vectorD,c,d)

# %%
vectorE = np.array([7,3])
vectorF = np.array([21,5])
e = np.arange(-10,10,.15)
f = np.arange(-10,10,.15)
plot_vectors(vectorE,vectorF,e,f)

# %% [markdown]
# #### Flowchart
# ![5thflow.png](attachment:5thflow.png)

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# Append your discussion at the end of the results section of your report just before your conclusion. Try to answer the following questions. Do not forget to cite your sources.

# %% [markdown]
# 1. You might have notices that the dimensions plot of linear combinations change according to its rank. If a vector is $\mathbb{R}=1$ the plot of its linear combination is one-dimensional or a line, and if $\mathbb{R}=2$ the plot is a plane. What will be the shape of the vector visualization if $\mathbb{R} = 3$ and if $\mathbb{R} = 4$?
#
# 2. Kindly discuss the role of unit vectors in relation to liner combinations.

# %% [markdown]
# ## Conclusion guide

# %% [markdown]
# For your conclusion synthesize the concept and application of the laboratory. Briefly discuss what you have learn and achieved in this activity. At the end of your conclusion try to answer the question : "How can you apply the concept of linear combination in engineeing or real-life situations?".
